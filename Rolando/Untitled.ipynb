# %%
#dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
path = "../resources/BEA.gov/CAINC1 Personal Income Summary Personal Income, Population, Per Capita_multi-cities.csv"
path2 = "../resources/BEA.gov/CAINC4 Personal Income and Employment by Major Component_multi-cities.csv"
df = pd.DataFrame(pd.read_csv(path))
df2 = pd.DataFrame(pd.read_csv(path2))

# %%
df.head()
# Out:
#    GeoFips                                            GeoName  LineCode  \
# 0    12420  Austin-Round Rock-Georgetown, TX (Metropolitan...         1
# 1    12420  Austin-Round Rock-Georgetown, TX (Metropolitan...         2
# 2    12420  Austin-Round Rock-Georgetown, TX (Metropolitan...         3
# 3    14460  Boston-Cambridge-Newton, MA-NH (Metropolitan S...         1
# 4    14460  Boston-Cambridge-Newton, MA-NH (Metropolitan S...         2
#
#                                Description       2010       2011       2012  \
# 0   Personal income (thousands of dollars)   70355303   77881693   85635903
# 1                  Population (persons) 1/    1727528    1780605    1834926
# 2  Per capita personal income (dollars) 2/      40726      43739      46670
# 3   Personal income (thousands of dollars)  265132347  278612314  291048881
# 4                  Population (persons) 1/    4566449    4609467    4656698
#
#         2013       2014       2015       2016       2017       2018
# ...

# %%
df2
# Out:
#      GeoFips                                            GeoName  LineCode  \
# 0      12420  Austin-Round Rock-Georgetown, TX (Metropolitan...       NaN
# 1      12420  Austin-Round Rock-Georgetown, TX (Metropolitan...      10.0
# 2      12420  Austin-Round Rock-Georgetown, TX (Metropolitan...      11.0
# 3      12420  Austin-Round Rock-Georgetown, TX (Metropolitan...      12.0
# 4      12420  Austin-Round Rock-Georgetown, TX (Metropolitan...      20.0
# ..       ...                                                ...       ...
# 103    42660  Seattle-Tacoma-Bellevue, WA (Metropolitan Stat...      72.0
# 104    42660  Seattle-Tacoma-Bellevue, WA (Metropolitan Stat...       NaN
# 105    42660  Seattle-Tacoma-Bellevue, WA (Metropolitan Stat...    7010.0
# 106    42660  Seattle-Tacoma-Bellevue, WA (Metropolitan Stat...    7020.0
# 107    42660  Seattle-Tacoma-Bellevue, WA (Metropolitan Stat...    7040.0
#
#                                 Description        2010        2011  \
# ...
