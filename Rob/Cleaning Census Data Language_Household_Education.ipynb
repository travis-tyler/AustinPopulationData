# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import CSV file

file1 = "../Resources/Census.gov/DP02_Language_Household_Education/ACSDP1Y2010.DP02_data_with_overlays_2020-03-17T221905.csv"
file2 = "../Resources/Census.gov/DP02_Language_Household_Education/ACSDP1Y2011.DP02_data_with_overlays_2020-03-17T221905.csv"
file3 = "../Resources/Census.gov/DP02_Language_Household_Education/ACSDP1Y2012.DP02_data_with_overlays_2020-03-17T221905.csv"
file4 = "../Resources/Census.gov/DP02_Language_Household_Education/ACSDP1Y2013.DP02_data_with_overlays_2020-03-17T221905.csv"
file5 = "../Resources/Census.gov/DP02_Language_Household_Education/ACSDP1Y2014.DP02_data_with_overlays_2020-03-17T221905.csv"
file6 = "../Resources/Census.gov/DP02_Language_Household_Education/ACSDP1Y2015.DP02_data_with_overlays_2020-03-17T221905.csv"
file7 = "../Resources/Census.gov/DP02_Language_Household_Education/ACSDP1Y2016.DP02_data_with_overlays_2020-03-17T221905.csv"
file8 = "../Resources/Census.gov/DP02_Language_Household_Education/ACSDP1Y2017.DP02_data_with_overlays_2020-03-17T221905.csv"
file9 = "../Resources/Census.gov/DP02_Language_Household_Education/ACSDP1Y2018.DP02_data_with_overlays_2020-03-17T221905.csv"

data1 = pd.read_csv(file1)
data_2010 = pd.DataFrame(data1).transpose()
data_2010.head()
# Out:
#                                                              0  \
# GEO_ID                                                      id
# NAME                                      Geographic Area Name
# DP02_0003E   Estimate!!HOUSEHOLDS BY TYPE!!Family household...
# DP02_0003PE  Percent!!HOUSEHOLDS BY TYPE!!Family households...
# DP02_0004E   Estimate!!HOUSEHOLDS BY TYPE!!Family household...
#
#                               1
# GEO_ID         1600000US4805000
# NAME         Austin city, Texas
# DP02_0003E                88908
# DP02_0003PE                27.5
# DP02_0004E               112882

# %%
test_file = "../Resources/Census.gov/Test_Delimited.csv"

data3 = pd.read_csv(test_file)
data_df = pd.DataFrame(data3)
data_df
# Out:
#           GEO_ID                        id              Unnamed: 2  \
# 0           NAME      Geographic Area Name                     NaN
# 1     DP02_0003E                  Estimate      HOUSEHOLDS BY TYPE
# 2    DP02_0003PE                   Percent      HOUSEHOLDS BY TYPE
# 3     DP02_0004E                  Estimate      HOUSEHOLDS BY TYPE
# 4     DP02_0003M  Estimate Margin of Error      HOUSEHOLDS BY TYPE
# 5    DP02_0003PM   Percent Margin of Error      HOUSEHOLDS BY TYPE
# 6     DP02_0004M  Estimate Margin of Error      HOUSEHOLDS BY TYPE
# 7     DP02_0001E                  Estimate      HOUSEHOLDS BY TYPE
# 8    DP02_0004PE                   Percent      HOUSEHOLDS BY TYPE
# 9     DP02_0006E                  Estimate      HOUSEHOLDS BY TYPE
# 10    DP02_0007M  Estimate Margin of Error      HOUSEHOLDS BY TYPE
# 11    DP02_0001M  Estimate Margin of Error      HOUSEHOLDS BY TYPE
# 12   DP02_0004PM   Percent Margin of Error      HOUSEHOLDS BY TYPE
# ...
